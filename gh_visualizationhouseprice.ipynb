# %%
import pandas as pd

# %%
houseprice_df=pd.read_csv(r"D:\sam_py_course\july 24\House_Price.csv")

# %%
houseprice_df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr_df= houseprice_df.corr(numeric_only= True)

# %%
plt.figure(figsize= (10,8))
sns.heatmap(corr_df,annot=True,vmin=-1)
# Out:
# <Axes: >

# %%
plt.hist(houseprice_df['price'])
# Out:
# (array([ 21.,  54.,  82., 155.,  84.,  41.,  31.,   7.,  10.,  21.]),
#  array([ 5. ,  9.5, 14. , 18.5, 23. , 27.5, 32. , 36.5, 41. , 45.5, 50. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(houseprice_df['waterbody'])
# Out:
# (array([183.,   0.,   0.,  97.,   0.,   0., 155.,   0.,   0.,  71.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(houseprice_df['n_hot_rooms'])
# Out:
# (array([504.,   0.,   0.,   0.,   0.,   0.,   0.,   1.,   0.,   1.]),
#  array([ 10.0576 ,  19.16384,  28.27008,  37.37632,  46.48256,  55.5888 ,
#          64.69504,  73.80128,  82.90752,  92.01376, 101.12   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(houseprice_df['airport'],houseprice_df['waterbody'])
plt.title('airport vs waterbody')
plt.xlabel('airport')
plt.ylabel('waterbody')
plt.show()

# %%
plt.scatter(houseprice_df['crime_rate'],houseprice_df['poor_prop'])
plt.title('crime_rate vs poor_prop')
plt.xlabel('crime_rate')
plt.ylabel('poor_prop')
plt.show()

# %%
plt.scatter(houseprice_df['n_hos_beds'],houseprice_df['n_hot_rooms'])
plt.title('n_hos_beds vs n_hot_rooms')
plt.xlabel('n_hos_beds')
plt.ylabel('n_hot_rooms')
plt.show()

# %%
import pandas as pd

# %%
PDiabetes_df= pd.read_csv(r"D:\sam_py_course\PredictDiabetes\diabetes.csv")

# %%
PDiabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr_df= PDiabetes_df.corr(numeric_only = True)

# %%
plt.figure(figsize= (10,8))
sns.heatmap(corr_df,annot= True,vmin= -1)
# Out:
# <Axes: >

# %%
plt.hist(PDiabetes_df['Pregnancies'])
# Out:
# (array([246., 178., 125.,  50.,  83.,  52.,  11.,  19.,   3.,   1.]),
#  array([ 0. ,  1.7,  3.4,  5.1,  6.8,  8.5, 10.2, 11.9, 13.6, 15.3, 17. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(PDiabetes_df['SkinThickness'])
# Out:
# (array([231., 107., 165., 175.,  78.,   9.,   2.,   0.,   0.,   1.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(PDiabetes_df['Insulin'])
# Out:
# (array([487., 155.,  70.,  30.,   8.,   9.,   5.,   1.,   2.,   1.]),
#  array([  0. ,  84.6, 169.2, 253.8, 338.4, 423. , 507.6, 592.2, 676.8,
#         761.4, 846. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(PDiabetes_df['Glucose'],PDiabetes_df['SkinThickness'])
plt.title('Glucose vs SkinThickness')
plt.xlabel('Glucose')
plt.ylabel('SkinThickness')
plt.show()

# %%
plt.scatter(PDiabetes_df['Insulin'],PDiabetes_df['BMI'])
plt.title('Insulin vs BMI')
plt.xlabel('Insulin')
plt.ylabel('BMI')
plt.show()

# %%
plt.scatter(PDiabetes_df['Pregnancies'],PDiabetes_df['Outcome'])
plt.title('Pregnancies vs Outcome')
plt.xlabel('Pregnancies')
plt.ylabel('Outcome')
plt.show()

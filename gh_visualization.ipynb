# %%
import pandas as pd

# %%
MovieClassification_df = pd.read_csv(r"D:\sam_py_course\july 24\Movie_classification.csv")

# %%
MovieClassification_df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr_df= MovieClassification_df.corr(numeric_only= True)

# %%
plt.figure(figsize= (10,8))
sns.heatmap(corr_df,annot= True,vmin=-1);

# %%
plt.hist(MovieClassification_df['Avg_age_actors']);

# %%
plt.hist(MovieClassification_df['Twitter_hastags'])
# Out:
# (array([504.,   0.,   0.,   0.,   0.,   0.,   0.,   1.,   0.,   1.]),
#  array([ 201.152 ,  383.2768,  565.4016,  747.5264,  929.6512, 1111.776 ,
#         1293.9008, 1476.0256, 1658.1504, 1840.2752, 2022.4   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(MovieClassification_df['Producer_rating'])
# Out:
# (array([  1.,   4.,   8.,  18.,  31.,  51.,  56.,  86., 136., 115.]),
#  array([4.03  , 4.5905, 5.151 , 5.7115, 6.272 , 6.8325, 7.393 , 7.9535,
#         8.514 , 9.0745, 9.635 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(MovieClassification_df['Critic_rating'])
plt.title('Critic plot')
plt.xlabel('Critic rating')
plt.ylabel('Count')
plt.show()

# %%
plt.scatter(MovieClassification_df['Critic_rating'],MovieClassification_df['Producer_rating'])
plt.title('critic vs producer plot')
plt.xlabel('critic rating')
plt.ylabel('producer rating')
plt.show()

# %%
plt.scatter(MovieClassification_df['Marketing expense'],MovieClassification_df['Production expense'])
plt.title('Marketing expense vs Production expense')
plt.xlabel('Marketing expense')
plt.ylabel('Production expense')
plt.show()

# %%
plt.scatter(MovieClassification_df['Producer_rating'],MovieClassification_df['Production expense'])
plt.title('Producer_rating vs Production expense')
plt.xlabel('Producer_rating')
plt.ylabel('Production expense')
plt.show()
